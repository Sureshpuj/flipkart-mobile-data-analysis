# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sys

# %%
dt=pd.read_csv("Flipcart_Mobile.csv")
dt
# Out:
#       Unnamed: 0                                       Model Name    Price  \
# 0              0  Samsung Galaxy A30s (Prism Crush Black, 128 GB)  15999.0
# 1              1  Samsung Galaxy A30s (Prism Crush White, 128 GB)  15990.0
# 2              2     Samsung Galaxy M40 (COCKTAIL ORANGE, 128 GB)  18499.0
# 3              3              Nokia 5.1 Plus (Black, Blue, 64 GB)  10399.0
# 4              4                     Nokia 6.2 (Ice White, 64 GB)  13990.0
# ...          ...                                              ...      ...
# 1867        1867                    Gionee Gpad G4 (Black, 16 GB)  18772.0
# 1868        1868      Alcatel Onetouch Idol X Plus (White, 16 GB)  14347.0
# 1869        1869            HTC Desire 816 Dual Sim (White, 8 GB)  27390.0
# 1870        1870         Samsung Galaxy S5 (Electric Blue, 16 GB)  21999.0
# 1871        1871           Samsung Galaxy S5 (Copper Gold, 16 GB)  21999.0
#
#      Discount  Avg Rating     Rating Count    Review Count  \
# ...

# %%
print("rows and columns :",dt.shape)
# Out:
# rows and columns : (1872, 13)

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1872 entries, 0 to 1871
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1872 non-null   int64
#  1   Model Name        1872 non-null   object
#  2   Price             1848 non-null   float64
#  3   Discount          732 non-null    object
#  4   Avg Rating        1841 non-null   float64
#  5   Rating Count      1843 non-null   object
#  6   Review Count      1843 non-null   object
#  7   Memory Details    1871 non-null   object
#  8   Screen Dimention  1872 non-null   object
#  9   Lens Detail       1870 non-null   object
#  10  Battery Capacity  1684 non-null   object
#  11  Processor         1805 non-null   object
#  12  Warranty          1851 non-null   object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 190.3+ KB

# %%
cdt=dt.fillna(0)
cdt
# Out:
#       Unnamed: 0                                       Model Name    Price  \
# 0              0  Samsung Galaxy A30s (Prism Crush Black, 128 GB)  15999.0
# 1              1  Samsung Galaxy A30s (Prism Crush White, 128 GB)  15990.0
# 2              2     Samsung Galaxy M40 (COCKTAIL ORANGE, 128 GB)  18499.0
# 3              3              Nokia 5.1 Plus (Black, Blue, 64 GB)  10399.0
# 4              4                     Nokia 6.2 (Ice White, 64 GB)  13990.0
# ...          ...                                              ...      ...
# 1867        1867                    Gionee Gpad G4 (Black, 16 GB)  18772.0
# 1868        1868      Alcatel Onetouch Idol X Plus (White, 16 GB)  14347.0
# 1869        1869            HTC Desire 816 Dual Sim (White, 8 GB)  27390.0
# 1870        1870         Samsung Galaxy S5 (Electric Blue, 16 GB)  21999.0
# 1871        1871           Samsung Galaxy S5 (Copper Gold, 16 GB)  21999.0
#
#      Discount  Avg Rating     Rating Count    Review Count  \
# ...

# %%
cdt.isnull().sum()
# Out:
# Unnamed: 0          0
# Model Name          0
# Price               0
# Discount            0
# Avg Rating          0
# Rating Count        0
# Review Count        0
# Memory Details      0
# Screen Dimention    0
# Lens Detail         0
# Battery Capacity    0
# Processor           0
# Warranty            0
# dtype: int64

# %%
cdt['Discount'] = cdt['Discount'].astype(str).str.extract('(\d+)').astype(float)
cdt
# Out:
#       Unnamed: 0                                       Model Name    Price  \
# 0              0  Samsung Galaxy A30s (Prism Crush Black, 128 GB)  15999.0
# 1              1  Samsung Galaxy A30s (Prism Crush White, 128 GB)  15990.0
# 2              2     Samsung Galaxy M40 (COCKTAIL ORANGE, 128 GB)  18499.0
# 3              3              Nokia 5.1 Plus (Black, Blue, 64 GB)  10399.0
# 4              4                     Nokia 6.2 (Ice White, 64 GB)  13990.0
# ...          ...                                              ...      ...
# 1867        1867                    Gionee Gpad G4 (Black, 16 GB)  18772.0
# 1868        1868      Alcatel Onetouch Idol X Plus (White, 16 GB)  14347.0
# 1869        1869            HTC Desire 816 Dual Sim (White, 8 GB)  27390.0
# 1870        1870         Samsung Galaxy S5 (Electric Blue, 16 GB)  21999.0
# 1871        1871           Samsung Galaxy S5 (Copper Gold, 16 GB)  21999.0
#
#       Discount  Avg Rating     Rating Count    Review Count  \
# ...

# %%
cdt['Rating Count'] = cdt['Rating Count'].astype(str).str.extract('(\d+)').astype(float)
cdt
# Out:
#       Unnamed: 0                                       Model Name    Price  \
# 0              0  Samsung Galaxy A30s (Prism Crush Black, 128 GB)  15999.0
# 1              1  Samsung Galaxy A30s (Prism Crush White, 128 GB)  15990.0
# 2              2     Samsung Galaxy M40 (COCKTAIL ORANGE, 128 GB)  18499.0
# 3              3              Nokia 5.1 Plus (Black, Blue, 64 GB)  10399.0
# 4              4                     Nokia 6.2 (Ice White, 64 GB)  13990.0
# ...          ...                                              ...      ...
# 1867        1867                    Gionee Gpad G4 (Black, 16 GB)  18772.0
# 1868        1868      Alcatel Onetouch Idol X Plus (White, 16 GB)  14347.0
# 1869        1869            HTC Desire 816 Dual Sim (White, 8 GB)  27390.0
# 1870        1870         Samsung Galaxy S5 (Electric Blue, 16 GB)  21999.0
# 1871        1871           Samsung Galaxy S5 (Copper Gold, 16 GB)  21999.0
#
#       Discount  Avg Rating  Rating Count    Review Count  \
# ...

# %%
cdt['Review Count'] = cdt['Review Count'].astype(str).str.extract('(\d+)').astype(float)
cdt
# Out:
#       Unnamed: 0                                       Model Name    Price  \
# 0              0  Samsung Galaxy A30s (Prism Crush Black, 128 GB)  15999.0
# 1              1  Samsung Galaxy A30s (Prism Crush White, 128 GB)  15990.0
# 2              2     Samsung Galaxy M40 (COCKTAIL ORANGE, 128 GB)  18499.0
# 3              3              Nokia 5.1 Plus (Black, Blue, 64 GB)  10399.0
# 4              4                     Nokia 6.2 (Ice White, 64 GB)  13990.0
# ...          ...                                              ...      ...
# 1867        1867                    Gionee Gpad G4 (Black, 16 GB)  18772.0
# 1868        1868      Alcatel Onetouch Idol X Plus (White, 16 GB)  14347.0
# 1869        1869            HTC Desire 816 Dual Sim (White, 8 GB)  27390.0
# 1870        1870         Samsung Galaxy S5 (Electric Blue, 16 GB)  21999.0
# 1871        1871           Samsung Galaxy S5 (Copper Gold, 16 GB)  21999.0
#
#       Discount  Avg Rating  Rating Count  Review Count  \
# ...

# %%
cdt['Battery Capacity'] = cdt['Battery Capacity'].astype(str).str.extract('(\d+)').astype(float)
cdt['Battery Capacity']
# Out:
# 0       4000.0
# 1       4000.0
# 2       3500.0
# 3       3060.0
# 4       3500.0
#          ...
# 1867    3200.0
# 1868    2500.0
# 1869    2600.0
# 1870    2800.0
# 1871    2800.0
# Name: Battery Capacity, Length: 1872, dtype: float64

# %%
cdt['Processor'] = cdt['Processor'].astype(str).str.extract('(\d+)').astype(float)
cdt['Processor']
# Out:
# 0       7904.0
# 1       7904.0
# 2          0.0
# 3          0.0
# 4          0.0
#          ...
# 1867       7.0
# 1868       0.0
# 1869     400.0
# 1870    5422.0
# 1871    5422.0
# Name: Processor, Length: 1872, dtype: float64

# %%
cdt.describe()
# Out:
#        Unnamed: 0          Price     Discount   Avg Rating  Rating Count  \
# count  1872.00000    1872.000000  1872.000000  1872.000000   1872.000000
# mean    935.50000   23067.287393     8.758547     4.147382    118.566774
# std     540.54417   20377.224341    14.232378     0.614578    225.946201
# min       0.00000       0.000000     0.000000     0.000000      0.000000
# 25%     467.75000   11490.000000     0.000000     4.000000      3.000000
# 50%     935.50000   14999.000000     0.000000     4.300000     11.000000
# 75%    1403.25000   25096.500000    15.000000     4.400000     90.000000
# max    1871.00000  144900.000000    79.000000     5.000000    997.000000
#
#        Review Count  Battery Capacity    Processor
# count   1872.000000       1872.000000  1847.000000
# mean     177.870726       3089.909188  1759.791554
# std      250.354781       1256.240071  2933.117580
# min        0.000000          0.000000     0.000000
# 25%        5.000000       2800.000000     9.000000
# ...

# %%
print("Total duplicate: ",cdt.duplicated().sum())
# Out:
# Total duplicate:  0

# %%
plt.title("Molile  Price by Discount(% Off) ",color="#333333")
x=cdt["Discount"].head(10)
y=cdt["Price"].head(10)
plt.bar(x,y, color="#8897AA",edgecolor="black",linewidth=1.5)
plt.ylabel("Price in RS.")
plt.xlabel("Discount % off")
# plt.show()
plt.gca().set_facecolor("#D7E2EB")
plt.show()

# %%
plt.title("Processor by Price")

x = cdt["Processor"] 
# Discounts as data for the histogram
plt.hist(x,color="#8897AA", edgecolor="black", linewidth=1) 

plt.ylabel("processor")  
plt.xlabel("Price")

plt.gca().set_facecolor("#D7E2EB")  # Set background color
plt.show()

# %%
cdt["Battery Capacity"] = cdt["Battery Capacity"].astype(str)  # Convert all values to string
cdt["Battery Capacity"] = cdt["Battery Capacity"].str.extract('(\d+)')  # Extract numeric part
cdt["Battery Capacity"] = cdt["Battery Capacity"].fillna(0).astype(int)  # Handle NaN and convert to int
cdt["Battery Capacity"]
# Out:
# 0       4000
# 1       4000
# 2       3500
# 3       3060
# 4       3500
#         ...
# 1867    3200
# 1868    2500
# 1869    2600
# 1870    2800
# 1871    2800
# Name: Battery Capacity, Length: 1872, dtype: int32

# %%
cdt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1872 entries, 0 to 1871
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1872 non-null   int64
#  1   Model Name        1872 non-null   object
#  2   Price             1872 non-null   float64
#  3   Discount          1872 non-null   float64
#  4   Avg Rating        1872 non-null   float64
#  5   Rating Count      1872 non-null   float64
#  6   Review Count      1872 non-null   float64
#  7   Memory Details    1872 non-null   object
#  8   Screen Dimention  1872 non-null   object
#  9   Lens Detail       1872 non-null   object
#  10  Battery Capacity  1872 non-null   int32
#  11  Processor         1847 non-null   float64
#  12  Warranty          1872 non-null   object
# dtypes: float64(6), int32(1), int64(1), object(5)
# memory usage: 182.9+ KB

# %%
plt.scatter(cdt["Battery Capacity"], cdt["Avg Rating"], color="#8897AA", edgecolor="black", linewidth=0.9) 

plt.xlabel("Battery Capacity in mAh Li-ion Battery")
plt.ylabel("Average Rating")
plt.title("Battery Capacity vs Average Rating")
plt.gca().set_facecolor("#D7E2EB")
plt.grid(True)
plt.show()

# %%
filtered_data = cdt[cdt["Price"] > 50000]
# Sorting by Price in descending order and selecting top 10
top_10 = filtered_data.sort_values(by="Price").head(10)
x = top_10["Model Name"] 
y = top_10["Price"]  
plt.bar(x, y, color="#8897AA", edgecolor="black")
plt.title("Top 10 Phone Models Above ₹50000 by Price", color="#333333")
plt.xticks(rotation=45, ha="right", fontsize=5)
plt.xlabel("Mobile Model", fontsize=12)
plt.gca().set_facecolor("#D7E2EB")
plt.ylabel("Price (in ₹)")
plt.show()

# %%
plt.title("Spread of Avg Rating Across Different Phone Models",fontweight="bold")
x = cdt["Model Name"].head()
y = cdt["Avg Rating"]
sys.boxplot(x=x, y=y, palette="pastel")  
plt.xlabel("Phone Model", fontsize=12)
plt.ylabel("Average Rating", fontsize=12)
plt.gca().set_facecolor("#D7E2EB")
plt.xticks(rotation=45, ha="right",fontsize=5)
plt.show()

# %%
corr_matrix = cdt[["Price", "Avg Rating", "Battery Capacity"]].corr()

sys.heatmap(corr_matrix, cmap="coolwarm", fmt=".2f", linewidths=10)

plt.title("Correlation Matrix: Price, Ratings, and Battery",fontweight="bold")
plt.show()

# %%
price = cdt["Price"].head(10)
processor_counts = cdt["Processor"]  # Extracting processor names

plt.pie(price, labels=processor_counts.head(10), autopct="%1.1f%%", 
        colors=["#ff9999", "#66b3ff", "#99ff99", "#ffcc99", "#c2c2f0"], 
        startangle=140, shadow=True, wedgeprops={"edgecolor": "black"})

plt.title("Price Distribution of Top 10 Phones by Processor", fontsize=14, fontweight="bold", color="#333333")
plt.show()

# %%
# plt.title("")
sys.pairplot(cdt,hue='Memory Details',palette='bright')
# plt.gca().set_facecolor("#D7E2EB")
# Out:
# C:\Users\Hp\anaconda3\sm\sureshpujariA\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Select top 10 rows based on 'Battery Capacity'
top_10 = cdt.nlargest(10, 'Battery Capacity')
# Create a boxplot using the filtered data
# plt.plot(x='Battery Capacity', y='Lens Detail', data=top_10, palette='Blues')
plt.bar(top_10["Battery Capacity"], top_10["Lens Detail"], color='black')
plt.xlabel("Battery Capacity")
plt.ylabel("Lens Detail")
plt.title("Battery Capacity vs Lens Detail (Top 10)")
plt.yticks(rotation=45, ha="right",fontsize=5)
plt.gca().set_facecolor("#D7E2EB")

# %%
x = cdt["Battery Capacity"].head(10) 
y = cdt["Discount"].head(10)
plt.xlabel("Battery Capacity (mAh)")
plt.ylabel("Discount (%)")
plt.title("Battery Capacity vs Discount")

plt.plot(x, y, marker='o', linestyle='-.', color='#333333', label="Discount Trend",markerfacecolor='red')
plt.gca().set_facecolor("#D7E2EB")

# %%
cdt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1872 entries, 0 to 1871
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1872 non-null   int64
#  1   Model Name        1872 non-null   object
#  2   Price             1872 non-null   float64
#  3   Discount          1872 non-null   float64
#  4   Avg Rating        1872 non-null   float64
#  5   Rating Count      1872 non-null   float64
#  6   Review Count      1872 non-null   float64
#  7   Memory Details    1872 non-null   object
#  8   Screen Dimention  1872 non-null   object
#  9   Lens Detail       1872 non-null   object
#  10  Battery Capacity  1872 non-null   int32
#  11  Processor         1847 non-null   float64
#  12  Warranty          1872 non-null   object
# dtypes: float64(6), int32(1), int64(1), object(5)
# memory usage: 182.9+ KB

# %%
max_discount = pd.Series(cdt['Discount'].max(), name="maximum Discount")
print(max_discount)
# Out:
# 0    79.0
# Name: maximum Discount, dtype: float64

# %%
y = cdt["Model Name"]
# Create a count plot
sys.countplot(y=y, order=y.value_counts().index[:13],palette="pastel")
plt.gca().set_facecolor("#D7E2EB")

# Add title
plt.title("Top 13 mobile model by count")

# Show the plot
plt.show()

# %%
cdt.describe()
# Out:
#        Unnamed: 0          Price     Discount   Avg Rating  Rating Count  \
# count  1872.00000    1872.000000  1872.000000  1872.000000   1872.000000
# mean    935.50000   23067.287393     8.758547     4.147382    118.566774
# std     540.54417   20377.224341    14.232378     0.614578    225.946201
# min       0.00000       0.000000     0.000000     0.000000      0.000000
# 25%     467.75000   11490.000000     0.000000     4.000000      3.000000
# 50%     935.50000   14999.000000     0.000000     4.300000     11.000000
# 75%    1403.25000   25096.500000    15.000000     4.400000     90.000000
# max    1871.00000  144900.000000    79.000000     5.000000    997.000000
#
#        Review Count  Battery Capacity    Processor
# count   1872.000000       1872.000000  1847.000000
# mean     177.870726       3089.909188  1759.791554
# std      250.354781       1256.240071  2933.117580
# min        0.000000          0.000000     0.000000
# 25%        5.000000       2800.000000     9.000000
# ...

# %% [markdown]
# The dataset contains details of 1,872 smartphones, including specifications, pricing, and user ratings.
# Some columns, like discounts and battery capacity, have missing values, which may impact analysis.
# It is useful for comparing smartphone features and understanding market trends.
